# %% [markdown]
# # 1. 필요 Library 설치

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/fd/a0/ccb3094026649cda4acd55bf2c3822bb8c277eb11446d13d384e5be35257/folium-0.10.1-py2.py3-none-any.whl (91kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\woong\anaconda3\lib\site-packages (from folium) (2.10)
# Requirement already satisfied: requests in c:\users\woong\anaconda3\lib\site-packages (from folium) (2.21.0)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: numpy in c:\users\woong\anaconda3\lib\site-packages (from folium) (1.16.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\woong\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\woong\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\woong\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\woong\anaconda3\lib\site-packages (from requests->folium) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\woong\anaconda3\lib\site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: six in c:\users\woong\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.12.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.10.1

# %% [markdown]
# # 2. 필요 Library 불러오기

# %%
import os

import pandas as pd
import numpy as np

import folium

import warnings
warnings.filterwarnings('ignore')

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager

# %% [markdown]
# # 3. 서울 카페 정보 데이터 로드하기

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'CH3. Cafe 창업 하기 전에 보세요.ipynb',
#  'map.html',
#  'seoul_cafe_location.csv',
#  'seoul_cafe_map.html',
#  'starbucks-logo.png']

# %%
df = pd.read_csv('seoul_cafe_location.csv', encoding = 'ms949', engine = 'python')
df.head()
# Out:
#              상호명         지점명     상권업종소분류명    시도명  시군구명  행정동명          경도  \
# 0  커피빈코리아선릉로93길점  코리아선릉로93길점  커피전문점/카페/다방  서울특별시   강남구  역삼1동  127.047883
# 1          스완카페트         NaN  커피전문점/카페/다방  서울특별시  영등포구  대림3동  126.897710
# 2             왕실         NaN  커피전문점/카페/다방  서울특별시    중구    명동  126.982419
# 3            커피빈      코리아교대점  커피전문점/카페/다방  서울특별시   서초구  서초1동  127.014217
# 4   고려대학교교육관쎄리오점         NaN  커피전문점/카페/다방  서울특별시   성북구   안암동  127.031702
#
#           위도
# 0  37.505675
# 1  37.503693
# 2  37.562274
# 3  37.492388
# 4  37.588485

# %% [markdown]
# # 4. 데이터 전처리하기

# %%
df['상호명'].value_counts()
# Out:
# 간단하지만특별한화피디Cafe    1188
# 이디야커피               401
# 스타벅스                299
# 커피빈                 146
# 투썸플레이스              127
# 할리스커피               101
# 커피베이                 91
# 공차                   91
# 카페베네                 90
# 쥬씨                   89
# 엔제리너스                84
# 탐앤탐스                 83
# 빽다방                  77
# 요거프레소                61
# 커피에반하다               61
# 토프레소                 56
# 파스쿠찌                 56
# 쥬스식스                 42
# 커피나무                 42
# 커피마마                 39
# 커피하우스                38
# 더카페                  37
# 할리스                  30
# 커피니                  29
# 떼루와                  26
# 셀렉토커피                25
# 폴바셋                  24
# 달콤커피                 24
# 메가커피                 23
# 더치앤빈                 22
#                    ...
# 로비                    1
# 커핀그루나루평창동점            1
# 캔모아대학로                1
# 10000LABCOFFEE        1
# 자스                    1
# 브루테크네                 1
# 썬빌인사이드                1
# 올라카페                  1
# 카페보라                  1
# 유한테크노스커피프린스           1
# 커피앤밀                  1
# 철도공익복지재단영             1
# 마리웨일마카롱상암SBA점         1
# Coffeetreeya          1
# 로미오와줄리엣               1
# 투썸서초비씨카드사옥            1
# 이립스                   1
# 레드망고                  1
# 터치까페                  1
# 닻별                    1
# 카페라엘스                 1
# 스타벅스신촌오거리점            1
# 공간만화카페                1
# 가비1896                1
# 방방키즈카페                1
# 더비                    1
# JUICY                 1
# AREACOFFEE            1
# 이비엠                   1
# 해밀                    1
# Name: 상호명, Length: 12503, dtype: int64

# %%
starbucks = []

for i in range(df.shape[0]) :
    if '스타벅스' in df['상호명'][i] :
        starbucks.append(df['상호명'][i])

# %%
starbucks
# Out:
# ['스타벅스',
#  '스타벅스종로3가점',
#  '스타벅스',
#  '스타벅스커피여의도IFC1F',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스신림사거리점',
#  '스타벅스',
#  '스타벅스커피홍대역',
#  '스타벅스',
#  '스타벅스새문안로점',
#  '스타벅스연신내역',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스올림픽평화의문점',
#  '스타벅스',
#  '스타벅스가락시장역점',
#  '스타벅스외대점',
#  '스타벅스연세백양로점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스연대동문',
#  '스타벅스',
#  '스타벅스명지대점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스석촌역',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스압구정로데오역',
#  '스타벅스',
#  '스타벅스사당점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스서울대입구역점',
#  '스타벅스',
#  '스타벅스신림점',
#  '스타벅스강남삼성타운점',
#  '스타벅스',
#  '스타벅스신촌명물거리점',
#  '스타벅스',
#  '스타벅스광장점',
#  '스타벅스',
#  '스타벅스건국클래식점',
#  '스타벅스명동미래',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스삼선교점',
#  '스타벅스연희DT점',
#  '스타벅스커피여의도호성',
#  '스타벅스충정타워',
#  '스타벅스올림픽공원북문점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스방배카페입구',
#  '스타벅스이수역점',
#  '스타벅스종각점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스W-MALL점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스용산역점',
#  '스타벅스마포일진빌딩점',
#  '스타벅스',
#  '스타벅스천호로데오점',
#  '스타벅스',
#  '스타벅스중계역점',
#  '스타벅스명동메트로',
#  '스타벅스마포아크로타워점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스남부터미널2점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스구로디지털로점',
#  '스타벅스',
#  '스타벅스중랑구청점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스논현힐탑',
#  '스타벅스종로관수점',
#  '스타벅스삼성도심공항점',
#  '스타벅스',
#  '스타벅스종로2가점',
#  '스타벅스선정릉역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스미아역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스선릉로점',
#  '스타벅스',
#  '스타벅스명동역',
#  '스타벅스',
#  '스타벅스역삼럭키',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스이태원거리점',
#  '스타벅스커피신도림디큐브시티B2',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스교대역점',
#  '스타벅스구로에이스트윈타워1점',
#  '스타벅스을지로입구',
#  '스타벅스서울중앙우체국점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스구로하이엔드점',
#  '스타벅스남산스테이트',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스명일이마트점',
#  '스타벅스목동점',
#  '스타벅스삼성교점',
#  '스타벅스조선호텔후문',
#  '스타벅스',
#  '스타벅스커리학동사거리점',
#  '스타벅스서울교대점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스강북구청사거리점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스청담사거리점',
#  '스타벅스방이역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스강변역점',
#  '스타벅스올림픽공원남문점',
#  '스타벅스종로평창',
#  '스타벅스서초파라곤점',
#  '스타벅스명동중앙로',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스신압구정점',
#  '스타벅스',
#  '스타벅스광화문역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스서소문배재',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스커피가산그레이트',
#  '스타벅스여의도점',
#  '스타벅스세종로점',
#  '스타벅스',
#  '스타벅스경복궁역',
#  '스타벅스을지로센타',
#  '스타벅스차병원사거리',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스예술의전당점',
#  '스타벅스중랑역점',
#  '스타벅스상봉역점',
#  '스타벅스사당로데오점',
#  '스타벅스학여울점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스구파발역점',
#  '스타벅스신천역점',
#  '스타벅스숙대입구역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스커피신도림디큐브시티2F',
#  '스타벅스커피가산브이타워',
#  '스타벅스동교삼거리점',
#  '스타벅스',
#  '스타벅스차병원사거리점',
#  '스타벅스가든파이브',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스뱅뱅사거리점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스석촌서호점',
#  '스타벅스',
#  '스타벅스경복아파트점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스동교점',
#  '스타벅스',
#  '스타벅스투',
#  '스타벅스월계이마트점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스상일동점',
#  '스타벅스',
#  '스타벅스신촌점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스상암DMC센트럴몰점',
#  '스타벅스삼청동점',
#  '스타벅스',
#  '스타벅스숭실대점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스역삼역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스홍대삼거리점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스구산역점',
#  '스타벅스',
#  '스타벅스광화문점',
#  '스타벅스청량리역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스합정메세나몰점',
#  '스타벅스대치점',
#  '스타벅스광운대점',
#  '스타벅스',
#  '스타벅스석촌호수점',
#  '스타벅스홍대갤러리점',
#  '스타벅스목동5단지점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스숙대점',
#  '스타벅스서소문배재점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스상암디지털큐브점상암디지털큐브점',
#  '스타벅스한성대입구역점',
#  '스타벅스',
#  '스타벅스송파사거리점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스잠실점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스가산디지털단지점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스금천독산점',
#  '스타벅스',
#  '스타벅스노원케이티점',
#  '스타벅스',
#  '스타벅스길동사거리점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스오목교역점',
#  '스타벅스',
#  '스타벅스코엑스사거리점',
#  '스타벅스황학캐슬점',
#  '스타벅스고대프라자점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스월드컵경기장점',
#  '스타벅스',
#  '스타벅스압구정로데오역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스강남에비뉴점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스연신내역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스명동역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스명동길점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스종로수송점',
#  '스타벅스',
#  '스타벅스엔터식스한양대점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스마포트라팰점',
#  '스타벅스방배카페입구점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스둔촌동점',
#  '스타벅스미아사거리역점',
#  '스타벅스',
#  '스타벅스신설동역점',
#  '스타벅스화곡동점',
#  '스타벅스종암점',
#  '스타벅스',
#  '스타벅스서교동사거리점',
#  '스타벅스역삼럭키점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스소공로북창점',
#  '스타벅스포스코사거리점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스동묘앞역점동묘앞역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스송파방이DT점',
#  '스타벅스청계산입구역점',
#  '스타벅스',
#  '스타벅스숭실대입구역점',
#  '스타벅스약수역점',
#  '스타벅스회현역점',
#  '스타벅스',
#  '스타벅스명동입구점',
#  '스타벅스신촌오거리점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스염창역점',
#  '스타벅스마포이마트점',
#  '스타벅스강남우성점',
#  '스타벅스양천향교역점',
#  '스타벅스',
#  '스타벅스중구저동점',
#  '스타벅스',
#  '스타벅스영등포신길DT점',
#  '스타벅스충정타워점',
#  '스타벅스대치사거리점',
#  '스타벅스',
#  '스타벅스합정점',
#  '스타벅스가산디지털단지역점',
#  '스타벅스압구정점',
#  '스타벅스커피마포염리',
#  '스타벅스낙성대DT점',
#  '스타벅스성신여대정문',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스한남동점',
#  '스타벅스강동역점',
#  '스타벅스',
#  '스타벅스대치은마사거리점',
#  '스타벅스',
#  '스타벅스화곡DT점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스송파구청점',
#  '스타벅스신세계본점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스신사가로수점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스양천향교역',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스서강광흥창역점',
#  '스타벅스서울대역점',
#  '스타벅스청담영동대로점',
#  '스타벅스강남점',
#  '스타벅스',
#  '스타벅스강남오거리점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스황학사거리점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스문정역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스송파위례점',
#  '스타벅스문정하비오점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스커피강남대로신사',
#  '스타벅스잠실대교남단점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스양천향교역',
#  '스타벅스외대정문점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스경희대삼거리점',
#  '스타벅스신세계본점5F',
#  '스타벅스이수역사거리점',
#  '스타벅스공릉역점',
#  '스타벅스',
#  '스타벅스구로디지털타워점',
#  '스타벅스',
#  '스타벅스노원마들역점',
#  '스타벅스마곡나루역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스신대방삼거리역점',
#  '스타벅스역점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스신도림점',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스공덕',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스방화DT',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스',
#  '스타벅스']

# %%
def unite_cafe_name(x) :
    if '스타벅스' in x :
        return '스타벅스'
    elif '커피빈' in x :
        return '커피빈'
    elif '할리스' in x :
        return '할리스'
    elif '투썸' in x :
        return '투썸플레이스'
    elif '이디야' in x :
        return '이디야'
    elif '공차' in x :
        return '공차'
    elif '카페베네' in x :
        return '카페베네'
    elif '엔제리너스' in x :
        return '엔제리너스'
    elif '탐앤탐스' in x :
        return '엔제리너스'
    elif '빽다방' in x :
        return '빽다방'
    
    else :
        return x

# %%
df.loc[:, '상호명'] = df['상호명'].apply(lambda x : unite_cafe_name(x))

# %%
df.head()
# Out:
#             상호명         지점명     상권업종소분류명    시도명  시군구명  행정동명          경도  \
# 0           커피빈  코리아선릉로93길점  커피전문점/카페/다방  서울특별시   강남구  역삼1동  127.047883
# 1         스완카페트         NaN  커피전문점/카페/다방  서울특별시  영등포구  대림3동  126.897710
# 2            왕실         NaN  커피전문점/카페/다방  서울특별시    중구    명동  126.982419
# 3           커피빈      코리아교대점  커피전문점/카페/다방  서울특별시   서초구  서초1동  127.014217
# 4  고려대학교교육관쎄리오점         NaN  커피전문점/카페/다방  서울특별시   성북구   안암동  127.031702
#
#           위도
# 0  37.505675
# 1  37.503693
# 2  37.562274
# 3  37.492388
# 4  37.588485

# %% [markdown]
# # 5. 서울 Top 20 카페 점포수 시각화하기

# %%
df['상호명'].value_counts()
# Out:
# 간단하지만특별한화피디Cafe    1188
# 스타벅스                502
# 이디야                 492
# 투썸플레이스              255
# 엔제리너스               254
# 커피빈                 229
# 할리스                 209
# 빽다방                 135
# 공차                  135
# 카페베네                133
# 커피베이                 91
# 쥬씨                   89
# 요거프레소                61
# 커피에반하다               61
# 파스쿠찌                 56
# 토프레소                 56
# 커피나무                 42
# 쥬스식스                 42
# 커피마마                 39
# 커피하우스                38
# 더카페                  37
# 커피니                  29
# 떼루와                  26
# 셀렉토커피                25
# 폴바셋                  24
# 달콤커피                 24
# 메가커피                 23
# 더치앤빈                 22
# 카페띠아모                22
# 청년다방                 21
#                    ...
# 컵                     1
# 까페보니또                 1
# 우정                    1
# 씨앗카페느티                1
# 팔공티상암점                1
# 롤링크레페                 1
# 애드커피                  1
# CAFFESOSPESO          1
# cafelereve            1
# 나이스                   1
# 카페밀도                  1
# MEISTERCOFFEE         1
# 쥬스로                   1
# 광전다방                  1
# 구름뜬하늘                 1
# 커피볶는카페지팡              1
# 커피베이행당역점              1
# 카툰공감                  1
# 카페아폴로                 1
# 심리카페COM               1
# 샵에이블록                 1
# 브룩스빌커피앤티              1
# 로비                    1
# 커핀그루나루평창동점            1
# 캔모아대학로                1
# 10000LABCOFFEE        1
# 자스                    1
# 굴리엘모                  1
# 쉠락에프앤비                1
# 해밀                    1
# Name: 상호명, Length: 11714, dtype: int64

# %%
df_feature_rank = pd.DataFrame({'상호명':df['상호명'].value_counts().index.values, '점포수':df['상호명'].value_counts().values})

# %%
df_top20 = df_feature_rank.head(20)
df_top20
# Out:
#                 상호명   점포수
# 0   간단하지만특별한화피디Cafe  1188
# 1              스타벅스   502
# 2               이디야   492
# 3            투썸플레이스   255
# 4             엔제리너스   254
# 5               커피빈   229
# 6               할리스   209
# 7               빽다방   135
# 8                공차   135
# 9              카페베네   133
# 10             커피베이    91
# 11               쥬씨    89
# 12            요거프레소    61
# 13           커피에반하다    61
# 14             파스쿠찌    56
# 15             토프레소    56
# 16             커피나무    42
# 17             쥬스식스    42
# 18             커피마마    39
# 19            커피하우스    38

# %%
font_list = font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
print('사용가능한 TTF 폰트 개수:', len(font_list))
font_list[:10]
# Out:
# 사용가능한 TTF 폰트 개수: 745
# ['C:\\Windows\\Fonts\\TCCM____.TTF',
#  'C:\\WINDOWS\\Fonts\\MOD20.TTF',
#  'C:\\WINDOWS\\Fonts\\verdanaz.ttf',
#  'C:\\WINDOWS\\Fonts\\전주완판본 각L.ttf',
#  'C:\\Windows\\Fonts\\FRAMDCN.TTF',
#  'C:\\Windows\\Fonts\\MP.TTF',
#  'C:\\Windows\\Fonts\\ANTQUABI.TTF',
#  'C:\\WINDOWS\\Fonts\\BKANT.TTF',
#  'C:\\Windows\\Fonts\\OUTLOOK.TTF',
#  'C:\\WINDOWS\\Fonts\\CASTELAR.TTF']

# %%
font_fname = 'C:\\Windows\\Fonts\\HANDotumB.ttf'
font_family = font_manager.FontProperties(fname=font_fname).get_name()
plt.rcParams["font.family"] = font_family

# %%
plt.figure(figsize=(12, 10))
ax = sns.barplot(x="점포수", y="상호명", data=df_top20, palette='Spectral')
plt.title('서울 카페 점포 수 Top20', fontsize = 16)
plt.yticks(fontsize=13)
for p in ax.patches:
    print(p)
    ax.annotate("%d" % p.get_width(), (p.get_x() + p.get_width(), p.get_y() + 0.9),
                xytext=(5, 7), textcoords='offset points')
plt.show()
# Out:
# Rectangle(xy=(0, -0.4), width=1188, height=0.8, angle=0)
# Rectangle(xy=(0, 0.6), width=502, height=0.8, angle=0)
# Rectangle(xy=(0, 1.6), width=492, height=0.8, angle=0)
# Rectangle(xy=(0, 2.6), width=255, height=0.8, angle=0)
# Rectangle(xy=(0, 3.6), width=254, height=0.8, angle=0)
# Rectangle(xy=(0, 4.6), width=229, height=0.8, angle=0)
# Rectangle(xy=(0, 5.6), width=209, height=0.8, angle=0)
# Rectangle(xy=(0, 6.6), width=135, height=0.8, angle=0)
# Rectangle(xy=(0, 7.6), width=135, height=0.8, angle=0)
# Rectangle(xy=(0, 8.6), width=133, height=0.8, angle=0)
# Rectangle(xy=(0, 9.6), width=91, height=0.8, angle=0)
# Rectangle(xy=(0, 10.6), width=89, height=0.8, angle=0)
# Rectangle(xy=(0, 11.6), width=61, height=0.8, angle=0)
# Rectangle(xy=(0, 12.6), width=61, height=0.8, angle=0)
# Rectangle(xy=(0, 13.6), width=56, height=0.8, angle=0)
# Rectangle(xy=(0, 14.6), width=56, height=0.8, angle=0)
# Rectangle(xy=(0, 15.6), width=42, height=0.8, angle=0)
# Rectangle(xy=(0, 16.6), width=42, height=0.8, angle=0)
# Rectangle(xy=(0, 17.6), width=39, height=0.8, angle=0)
# Rectangle(xy=(0, 18.6), width=38, height=0.8, angle=0)

# %%
df[df['상호명'] == '간단하지만특별한화피디Cafe']
# Out:
#                    상호명          지점명     상권업종소분류명    시도명  시군구명         행정동명  \
# 121    간단하지만특별한화피디Cafe    에델리아하이마트점  커피전문점/카페/다방  서울특별시   강남구         대치2동
# 254    간단하지만특별한화피디Cafe     카그뮤지컬예당점  커피전문점/카페/다방  서울특별시   서초구         서초3동
# 398    간단하지만특별한화피디Cafe       드마린논현점  커피전문점/카페/다방  서울특별시   강남구         논현2동
# 452    간단하지만특별한화피디Cafe       루이스신사점  커피전문점/카페/다방  서울특별시   강남구         논현1동
# 901    간단하지만특별한화피디Cafe       셀렉토스타점  커피전문점/카페/다방  서울특별시   성북구          석관동
# 915    간단하지만특별한화피디Cafe        모아가산점  커피전문점/카페/다방  서울특별시   금천구          가산동
# 1122   간단하지만특별한화피디Cafe         H무역점  커피전문점/카페/다방  서울특별시   강남구         삼성1동
# 1431   간단하지만특별한화피디Cafe  마마스미니현대압구정점  커피전문점/카페/다방  서울특별시   강남구          신사동
# 1437   간단하지만특별한화피디Cafe      드구띠에역삼점  커피전문점/카페/다방  서울특별시   강남구         역삼1동
# 1697   간단하지만특별한화피디Cafe   반디앤루니스코엑스점  커피전문점/카페/다방  서울특별시   강남구         삼성1동
# 1885   간단하지만특별한화피디Cafe     파스쿠찌연세대점  커피전문점/카페/다방  서울특별시  서대문구          신촌동
# 2123   간단하지만특별한화피디Cafe      리앙인디에프점  커피전문점/카페/다방  서울특별시   강남구         대치1동
# 2253   간단하지만특별한화피디Cafe   안젤로서초평화빌딩점  커피전문점/카페/다방  서울특별시   서초구         서초3동
# 2359   간단하지만특별한화피디Cafe         지대치점  커피전문점/카페/다방  서울특별시   강남구         대치1동
# 2908   간단하지만특별한화피디Cafe    느티나무137동점  커피전문점/카페/다방  서울특별시   관악구          대학동
# 3009   간단하지만특별한화피디Cafe     쉐어링동양생명점  커피전문점/카페/다방  서울특별시   종로구  종로1.2.3.4가동
# 3039   간단하지만특별한화피디Cafe        산다2호점  커피전문점/카페/다방  서울특별시   관악구         낙성대동
# 3074   간단하지만특별한화피디Cafe     아띠지아노이대점  커피전문점/카페/다방  서울특별시  서대문구          신촌동
# 3247   간단하지만특별한화피디Cafe       쟈스충무로점  커피전문점/카페/다방  서울특별시    중구           필동
# 3383   간단하지만특별한화피디Cafe     루고가든파이브점  커피전문점/카페/다방  서울특별시   송파구         문정2동
# 3591   간단하지만특별한화피디Cafe       블로그신천점  커피전문점/카페/다방  서울특별시   송파구         잠실본동
# 3611   간단하지만특별한화피디Cafe    마마스센트럴시티점  커피전문점/카페/다방  서울특별시   서초구         반포4동
# 3679   간단하지만특별한화피디Cafe     파스쿠찌가양역점  커피전문점/카페/다방  서울특별시   강서구         등촌3동
# 3954   간단하지만특별한화피디Cafe      센티모르교대점  커피전문점/카페/다방  서울특별시   서초구         서초1동
# 4057   간단하지만특별한화피디Cafe          NaN  커피전문점/카페/다방  서울특별시   종로구          부암동
# 4197   간단하지만특별한화피디Cafe       라첼타중량점  커피전문점/카페/다방  서울특별시   중랑구         상봉2동
# 4390   간단하지만특별한화피디Cafe     마마스센터원지점  커피전문점/카페/다방  서울특별시    중구           명동
# 4401   간단하지만특별한화피디Cafe    마마스상암MBC점  커피전문점/카페/다방  서울특별시   마포구          상암동
# 4458   간단하지만특별한화피디Cafe      디비베스미아점  커피전문점/카페/다방  서울특별시   성북구         길음2동
# 5204   간단하지만특별한화피디Cafe      루시카토두타점  커피전문점/카페/다방  서울특별시    중구          광희동
# ...                ...          ...          ...    ...   ...          ...
# 18246  간단하지만특별한화피디Cafe        코르소코모  커피전문점/카페/다방  서울특별시   강남구          청담동
# 18247  간단하지만특별한화피디Cafe      베르타플라워&  커피전문점/카페/다방  서울특별시   은평구          역촌동
# 18248  간단하지만특별한화피디Cafe          청량휴  커피전문점/카페/다방  서울특별시  동대문구          제기동
# 18249  간단하지만특별한화피디Cafe     제이더블유앤샤브  커피전문점/카페/다방  서울특별시  동대문구         이문2동
# 18252  간단하지만특별한화피디Cafe          르보땅  커피전문점/카페/다방  서울특별시   강동구         암사1동
# 18254  간단하지만특별한화피디Cafe        이룸스터디  커피전문점/카페/다방  서울특별시   양천구          목2동
# 18257  간단하지만특별한화피디Cafe         1969  커피전문점/카페/다방  서울특별시   은평구          대조동
# 18267  간단하지만특별한화피디Cafe          구스토  커피전문점/카페/다방  서울특별시   동작구          흑석동
# 18271  간단하지만특별한화피디Cafe         히스토리  커피전문점/카페/다방  서울특별시   양천구          목4동
# 18287  간단하지만특별한화피디Cafe          기리울  커피전문점/카페/다방  서울특별시   강동구           길동
# 18321  간단하지만특별한화피디Cafe          울리포  커피전문점/카페/다방  서울특별시   마포구         망원1동
# 18334  간단하지만특별한화피디Cafe         청순갈현  커피전문점/카페/다방  서울특별시   은평구         갈현1동
# 18353  간단하지만특별한화피디Cafe         에이전시  커피전문점/카페/다방  서울특별시   광진구           능동
# 18393  간단하지만특별한화피디Cafe    리빈테헤란로2호점  커피전문점/카페/다방  서울특별시   강남구         역삼2동
# 18403  간단하지만특별한화피디Cafe        기본스터디  커피전문점/카페/다방  서울특별시   강서구         방화1동
# 18408  간단하지만특별한화피디Cafe       두리안디저트  커피전문점/카페/다방  서울특별시   구로구         구로4동
# 18417  간단하지만특별한화피디Cafe          온21  커피전문점/카페/다방  서울특별시   용산구          한남동
# 18423  간단하지만특별한화피디Cafe         글루세라  커피전문점/카페/다방  서울특별시   강서구         가양1동
# 18430  간단하지만특별한화피디Cafe       로이베이커리  커피전문점/카페/다방  서울특별시   광진구         자양3동
# 18435  간단하지만특별한화피디Cafe     해피카우베이커리  커피전문점/카페/다방  서울특별시  서대문구          충현동
# 18454  간단하지만특별한화피디Cafe          비타민  커피전문점/카페/다방  서울특별시   종로구          교남동
# 18468  간단하지만특별한화피디Cafe         좋아진다  커피전문점/카페/다방  서울특별시   동작구         사당1동
# 18477  간단하지만특별한화피디Cafe          부티크  커피전문점/카페/다방  서울특별시   용산구        이태원2동
# 18478  간단하지만특별한화피디Cafe          문나잇  커피전문점/카페/다방  서울특별시   강북구          미아동
# 18481  간단하지만특별한화피디Cafe          청호휘  커피전문점/카페/다방  서울특별시   강서구         가양1동
# 18486  간단하지만특별한화피디Cafe      웨스트엔드문화  커피전문점/카페/다방  서울특별시   강서구         발산1동
# 18494  간단하지만특별한화피디Cafe          NaN  커피전문점/카페/다방  서울특별시    중구          소공동
# 18510  간단하지만특별한화피디Cafe          트리빈  커피전문점/카페/다방  서울특별시    중구           명동
# 18517  간단하지만특별한화피디Cafe        소스코리아  커피전문점/카페/다방  서울특별시   구로구         구로5동
# 18525  간단하지만특별한화피디Cafe      메이크잇카운트  커피전문점/카페/다방  서울특별시   동작구         사당1동
#
#                경도         위도
# 121    127.063815  37.494233
# 254    127.012347  37.480667
# 398    127.032971  37.510465
# 452    127.023566  37.516974
# 901    127.056891  37.610395
# 915    126.885794  37.476748
# 1122   127.059745  37.508608
# 1431   127.027447  37.527359
# 1437   127.032438  37.496557
# 1697   127.056253  37.512852
# 1885   126.937086  37.557495
# 2123   127.055213  37.496615
# 2253   127.012692  37.482797
# 2359   127.058815  37.497960
# 2908   126.959279  37.468030
# 3009   126.981418  37.570951
# 3039   126.956929  37.478569
# 3074   126.946259  37.557947
# 3247   126.991818  37.562760
# 3383   127.124941  37.477608
# 3591   127.079954  37.510741
# 3611   127.002393  37.503930
# 3679   126.853258  37.561585
# 3954   127.014377  37.491425
# 4057   126.964094  37.595723
# 4197   127.077097  37.592939
# 4390   126.985134  37.567388
# 4401   126.890966  37.581111
# 4458   127.028726  37.608392
# 5204   127.008761  37.568877
# ...           ...        ...
# 18246  127.042386  37.526922
# 18247  126.918962  37.600815
# 18248  127.042123  37.580208
# 18249  127.067370  37.599287
# 18252  127.130044  37.549424
# 18254  126.871490  37.538478
# 18257  126.927763  37.612581
# 18267  126.966187  37.504087
# 18271  126.864502  37.538934
# 18287  127.144628  37.535880
# 18321  126.905069  37.555869
# 18334  126.918526  37.625481
# 18353  127.078283  37.547239
# 18393  127.042683  37.501002
# 18403  126.811809  37.573718
# 18408  126.894024  37.491378
# 18417  126.999554  37.536182
# 18423  126.826977  37.567310
# 18430  127.068338  37.534311
# 18435  126.954041  37.563152
# 18454  126.965134  37.568845
# 18468  126.978154  37.479944
# 18477  126.990584  37.539277
# 18478  127.027124  37.626129
# 18481  126.831999  37.559620
# 18486  126.826697  37.553440
# 18494  126.973759  37.560703
# 18510  126.987039  37.567152
# 18517  126.888835  37.501961
# 18525  126.971763  37.476861
#
# [1188 rows x 8 columns]

# %% [markdown]
# # 6. 서울 지도에 카페 Top5 카페 점포수 시각화 하기

# %%
df_top20['상호명'][1:6]
# Out:
# 1      스타벅스
# 2       이디야
# 3    투썸플레이스
# 4     엔제리너스
# 5       커피빈
# Name: 상호명, dtype: object

# %%
def etc_cafe_name(x) :
    if x in list(df_top20['상호명'][1:6]) :
        return x
    else :
        return '기타_카페'

# %%
df.loc[:, '상호명'] = df['상호명'].apply(lambda x : etc_cafe_name(x))

# %%
df = df[df['상호명'] != '기타_카페']

# %%
df.head()
# Out:
#      상호명          지점명     상권업종소분류명    시도명 시군구명   행정동명          경도         위도
# 0    커피빈   코리아선릉로93길점  커피전문점/카페/다방  서울특별시  강남구   역삼1동  127.047883  37.505675
# 3    커피빈       코리아교대점  커피전문점/카페/다방  서울특별시  서초구   서초1동  127.014217  37.492388
# 7    커피빈  코리아대학로대명거리점  커피전문점/카페/다방  서울특별시  종로구    혜화동  127.000171  37.583149
# 12   커피빈      코리아선릉역점  커피전문점/카페/다방  서울특별시  강남구   역삼1동  127.048223  37.504750
# 23  스타벅스         이태원점  커피전문점/카페/다방  서울특별시  용산구  이태원1동  126.994781  37.534303

# %%
df['상호명'].value_counts()
# Out:
# 스타벅스      502
# 이디야       492
# 투썸플레이스    255
# 엔제리너스     254
# 커피빈       229
# Name: 상호명, dtype: int64

# %%
def cafe_color(x) :
    
    if x == '스타벅스' :
        return 'green'
    elif x == '이디야' :
        return 'blue'
    elif x == '투썸플레이스' :
        return 'red'
    elif x == '엔제리너스' :
        return 'orange'
    elif x == '커피빈' :
        return 'beige'

# %%
df['표시색상'] = df['상호명']

# %%
df.head()
# Out:
#      상호명          지점명     상권업종소분류명    시도명 시군구명   행정동명          경도         위도  \
# 0    커피빈   코리아선릉로93길점  커피전문점/카페/다방  서울특별시  강남구   역삼1동  127.047883  37.505675
# 3    커피빈       코리아교대점  커피전문점/카페/다방  서울특별시  서초구   서초1동  127.014217  37.492388
# 7    커피빈  코리아대학로대명거리점  커피전문점/카페/다방  서울특별시  종로구    혜화동  127.000171  37.583149
# 12   커피빈      코리아선릉역점  커피전문점/카페/다방  서울특별시  강남구   역삼1동  127.048223  37.504750
# 23  스타벅스         이태원점  커피전문점/카페/다방  서울특별시  용산구  이태원1동  126.994781  37.534303
#
#     표시색상
# 0    커피빈
# 3    커피빈
# 7    커피빈
# 12   커피빈
# 23  스타벅스

# %%
df.loc[:, '표시색상'] = df['표시색상'].apply(lambda x : cafe_color(x))

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index   상호명          지점명     상권업종소분류명    시도명 시군구명   행정동명          경도  \
# 0      0   커피빈   코리아선릉로93길점  커피전문점/카페/다방  서울특별시  강남구   역삼1동  127.047883
# 1      3   커피빈       코리아교대점  커피전문점/카페/다방  서울특별시  서초구   서초1동  127.014217
# 2      7   커피빈  코리아대학로대명거리점  커피전문점/카페/다방  서울특별시  종로구    혜화동  127.000171
# 3     12   커피빈      코리아선릉역점  커피전문점/카페/다방  서울특별시  강남구   역삼1동  127.048223
# 4     23  스타벅스         이태원점  커피전문점/카페/다방  서울특별시  용산구  이태원1동  126.994781
#
#           위도   표시색상
# 0  37.505675  beige
# 1  37.492388  beige
# 2  37.583149  beige
# 3  37.504750  beige
# 4  37.534303  green

# %%
df.shape
# Out:
# (1732, 10)

# %%
cafe_map = folium.Map(location=[df['위도'].median(), df['경도'].median()], zoom_start=12)

for i in range(1450) :
    
    folium.Marker(location=[df.loc[i, '위도'], df.loc[i, '경도']],
                  popup=df['상호명'][i],
                  icon=folium.Icon(color=df['표시색상'][i], icon='glass')).add_to(cafe_map)

cafe_map
#cafe_map.save('seoul_cafe_map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
